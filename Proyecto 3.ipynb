# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_file = 'IXIC.csv'
data = pd.read_csv(data_file, header = None)

# %%
x = data.index.values
y = data.iloc[:, 1].values

plt.figure()
plt.plot(x,y)
plt.show()

# %%
import pyomo_utilities

# %%
beta1 = pyomo_utilities.curve_polyfit(x, y, 1)
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 2
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03158402442932129
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta1
# Out:
# array([  4.51698948e+03,   3.75142194e+00])

# %%
yhat1 = beta1[0]+beta1[1]*x

plt.figure(figsize=(8,6))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat1, '-r', label = 'ajuste')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
beta2 = pyomo_utilities.curve_polyfit(x, y, 2)
yhat2 = beta2[0]+beta2[1]*x+beta2[2]*x**2

beta3 = pyomo_utilities.curve_polyfit(x, y, 3)
yhat3 = beta3[0]+beta3[1]*x+beta3[2]*x**2+beta3[3]*x**3

beta4 = pyomo_utilities.curve_polyfit(x, y, 4)
yhat4 = beta4[0]+beta4[1]*x+beta4[2]*x**2+beta4[3]*x**3+beta4[4]*x**4

beta5 = pyomo_utilities.curve_polyfit(x, y, 5)
yhat5 = beta5[0]+beta5[1]*x+beta5[2]*x**2+beta5[3]*x**3+beta5[4]*x**4+beta5[5]*x**5

beta6 = pyomo_utilities.curve_polyfit(x, y, 6)
yhat6 = beta6[0]+beta6[1]*x+beta6[2]*x**2+beta6[3]*x**3+beta6[4]*x**4+beta6[5]*x**5+beta6[6]*x**6

beta7 = pyomo_utilities.curve_polyfit(x, y, 7)
yhat7 = beta7[0]+beta7[1]*x+beta7[2]*x**2+beta7[3]*x**3+beta7[4]*x**4+beta7[5]*x**5+beta7[6]*x**6+beta7[7]*x**7

beta8 = pyomo_utilities.curve_polyfit(x, y, 8)
yhat8 = beta8[0]+beta8[1]*x+beta8[2]*x**2+beta8[3]*x**3+beta8[4]*x**4+beta8[5]*x**5+beta8[6]*x**6+beta8[7]*x**7+beta8[8]*x**8

beta9 = pyomo_utilities.curve_polyfit(x, y, 9)
yhat9 = beta9[0]+beta9[1]*x+beta9[2]*x**2+beta9[3]*x**3+beta9[4]*x**4+beta9[5]*x**5+beta9[6]*x**6+beta9[7]*x**7+beta9[8]*x**8+beta9[9]*x**9

beta10 = pyomo_utilities.curve_polyfit(x, y, 10)
yhat10 = beta10[0]+beta10[1]*x+beta10[2]*x**2+beta10[3]*x**3+beta10[4]*x**4+beta10[5]*x**5+beta10[6]*x**6+beta10[7]*x**7+beta10[8]*x**8+beta10[9]*x**9+beta10[10]*x**10
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 3
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.056649208068847656
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat1, '-r', label = 'ajuste 1')
plt.plot(x, yhat2, '-g', label = 'ajuste 2')
plt.plot(x, yhat3, '-k', label = 'ajuste 3')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat4, '-r', label = 'ajuste 4')
plt.plot(x, yhat5, '-g', label = 'ajuste 5')
plt.plot(x, yhat6, '-k', label = 'ajuste 6')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat7, '-r', label = 'ajuste 7')
plt.plot(x, yhat8, '-g', label = 'ajuste 8')
plt.plot(x, yhat9, '-y', label = 'ajuste 9')

plt.legend(loc = 'best')
plt.xlabel('$Dias$')
plt.ylabel('$Precio$')
plt.grid()
plt.show()

# %%
beta11 = pyomo_utilities.curve_polyfit(x, y, 11)
yhat11 = beta11[0]+beta11[1]*x+beta11[2]*x**2+beta11[3]*x**3+beta11[4]*x**4+beta11[5]*x**5+beta11[6]*x**6+beta11[7]*x**7+beta11[8]*x**8+beta11[9]*x**9+beta11[10]*x**10+beta11[11]*x**11

beta12 = pyomo_utilities.curve_polyfit(x, y, 12)
yhat12 = beta12[0]+beta12[1]*x+beta12[2]*x**2+beta12[3]*x**3+beta12[4]*x**4+beta12[5]*x**5+beta12[6]*x**6+beta12[7]*x**7+beta12[8]*x**8+beta12[9]*x**9+beta12[10]*x**10+beta12[11]*x**11+beta12[12]*x**12

beta13 = pyomo_utilities.curve_polyfit(x, y, 13)
yhat13 = beta13[0]+beta13[1]*x+beta13[2]*x**2+beta13[3]*x**3+beta13[4]*x**4+beta13[5]*x**5+beta13[6]*x**6+beta13[7]*x**7+beta13[8]*x**8+beta13[9]*x**9+beta13[10]*x**10+beta13[11]*x**11+beta13[12]*x**12+beta13[13]*x**13

beta14 = pyomo_utilities.curve_polyfit(x, y, 14)
yhat14 = beta14[0]+beta14[1]*x+beta14[2]*x**2+beta14[3]*x**3+beta14[4]*x**4+beta14[5]*x**5+beta14[6]*x**6+beta14[7]*x**7+beta14[8]*x**8+beta14[9]*x**9+beta14[10]*x**10+beta14[11]*x**11+beta14[12]*x**12+beta14[13]*x**10+beta14[14]*x**14

beta15 = pyomo_utilities.curve_polyfit(x, y, 15)
yhat15 = beta15[0]+beta15[1]*x+beta15[2]*x**2+beta15[3]*x**3+beta15[4]*x**4+beta15[5]*x**5+beta15[6]*x**6+beta15[7]*x**7+beta15[8]*x**8+beta15[9]*x**9+beta15[10]*x**10+beta15[11]*x**11+beta15[12]*x**12+beta15[13]*x**13+beta15[14]*x**14+beta15[15]*x**15
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 12
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
plt.figure(figsize=(15,10))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat11, '-r', label = 'ajuste 11')
plt.plot(x, yhat12, '-g', label = 'ajuste 12')
plt.plot(x, yhat13, '-y', label = 'ajuste 13')
plt.plot(x, yhat14, '-k', label = 'ajuste 14')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
beta20 = pyomo_utilities.curve_polyfit(x, y, 20)
yhat20 = beta20[0]+beta20[1]*x+beta20[2]*x**2+beta20[3]*x**3+beta20[4]*x**4+beta20[5]*x**5+beta20[6]*x**6+beta20[7]*x**7+beta20[8]*x**8+beta20[9]*x**9+beta20[10]*x**10+beta20[11]*x**11+beta20[12]*x**12+beta20[13]*x**13+beta20[14]*x**14+beta20[15]*x**15+beta20[16]*x**16+beta20[17]*x**17+beta20[18]*x**18+beta20[19]*x**19+beta20[20]*x**20

beta25 = pyomo_utilities.curve_polyfit(x, y, 25)
yhat25 = beta25[0]+beta25[1]*x+beta25[2]*x**2+beta25[3]*x**3+beta25[4]*x**4+beta25[5]*x**5+beta25[6]*x**6+beta25[7]*x**7+beta25[8]*x**8+beta25[9]*x**9+beta25[10]*x**10+beta25[11]*x**11+beta25[12]*x**12+beta25[13]*x**13+beta25[14]*x**14+beta25[15]*x**15+beta25[16]*x**16+beta25[17]*x**17+beta25[18]*x**18+beta25[19]*x**19+beta25[20]*x**20+beta25[21]*x**21+beta25[22]*x**22+beta25[23]*x**23+beta25[24]*x**24+beta25[25]*x**25

beta30 = pyomo_utilities.curve_polyfit(x, y, 30)
yhat30 = beta30[0]+beta30[1]*x+beta30[2]*x**2+beta30[3]*x**3+beta30[4]*x**4+beta30[5]*x**5+beta30[6]*x**6+beta30[7]*x**7+beta30[8]*x**8+beta30[9]*x**9+beta30[10]*x**10+beta30[11]*x**11+beta30[12]*x**12+beta30[13]*x**13+beta30[14]*x**14+beta30[15]*x**15+beta30[16]*x**16+beta30[17]*x**17+beta30[18]*x**18+beta30[19]*x**19+beta30[20]*x**20+beta30[21]*x**21+beta30[22]*x**22+beta30[23]*x**23+beta30[24]*x**24+beta30[25]*x**25+beta30[26]*x**26+beta30[27]*x**27+beta30[28]*x**28+beta30[29]*x**29+beta30[30]*x**30
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 21
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
plt.figure(figsize=(15,10))
plt.plot(x, y, '*b', label = 'datos')
plt.plot(x, yhat20, '-r', label = 'ajuste 20')
plt.plot(x, yhat25, '-g', label = 'ajuste 25')
plt.plot(x, yhat30, '-y', label = 'ajuste 30')
plt.plot(x, yhat9, '-k', label = 'ajuste 9')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
beta40 = pyomo_utilities.curve_polyfit(x, y, 40)
yhat40 = beta40.dot(np.array([x**i for i in range(41)]))

beta50 = pyomo_utilities.curve_polyfit(x, y, 50)
yhat50 = beta50.dot(np.array([x**i for i in range(51)]))

beta75 = pyomo_utilities.curve_polyfit(x, y, 75)
yhat75 = beta75.dot(np.array([x**i for i in range(76)]))

beta90 = pyomo_utilities.curve_polyfit(x, y, 90)
yhat90 = beta90.dot(np.array([x**i for i in range(91)]))


beta100 = pyomo_utilities.curve_polyfit(x, y, 100)
yhat100 = beta100.dot(np.array([x**i for i in range(101)]))
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 41
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
plt.figure(figsize = (8,6))
plt.plot(x, y, '*b', label = 'datos reales')
plt.plot(x, yhat100, '-k', label = 'ajuste 100')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
beta300 = pyomo_utilities.curve_polyfit(x, y, 300)
yhat300 = beta300.dot(np.array([x**i for i in range(301)]))
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 301
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
beta200 = pyomo_utilities.curve_polyfit(x, y, 200)
yhat200 = beta200.dot(np.array([x**i for i in range(201)]))
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 201
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
plt.figure(figsize = (8,6))
plt.plot(x, y, '*b', label = 'datos reales')
plt.plot(x, yhat100, '-k', label = 'ajuste 100')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
ems = []
ems.append(sum((y-yhat1)**2))
ems.append(sum((y-yhat2)**2))
ems.append(sum((y-yhat3)**2))
ems.append(sum((y-yhat4)**2))
ems.append(sum((y-yhat5)**2))
ems.append(sum((y-yhat6)**2))
ems.append(sum((y-yhat7)**2))
ems.append(sum((y-yhat8)**2))
ems.append(sum((y-yhat9)**2))
ems.append(sum((y-yhat10)**2))

ems.append(sum((y-yhat100)**2))
ems.append(sum((y-yhat200)**2))
ems.append(sum((y-yhat300)**2))

plt.figure(figsize = (8,6))
plt.plot(np.arange(13)+1, ems, '*b')
plt.xlabel('$n$')
plt.ylabel('$e_{ms}(n)$')
plt.show()

# %%
P1 = beta1.dot(np.array([272**i for i in range(2)]))
# DATO REAL = 5642.649902
P2 = beta1.dot(np.array([298**i for i in range(2)]))
# DATO REAL = 5861.72998
P3 = beta1.dot(np.array([320**i for i in range(2)]))
# DATO REAL = 5866.77002
P4 = beta1.dot(np.array([350**i for i in range(2)]))
# DATO REAL = 6163.02002
P5 = beta1.dot(np.array([377**i for i in range(2)]))
# DATO REAL = 6110.060059
P6 = beta1.dot(np.array([400**i for i in range(2)]))
# DATO REAL = 6351.560059
P7 = beta1.dot(np.array([419**i for i in range(2)]))
# DATO REAL = 6428.660156
P8 = beta1.dot(np.array([450**i for i in range(2)]))
# DATO REAL = 6624
P9 = beta1.dot(np.array([465**i for i in range(2)]))
# DATO REAL = 6786.439941
P10 = beta1.dot(np.array([480**i for i in range(2)]))
# DATO REAL = 6912.359863
P1,P2,P3,P4,P5,P6,P7,P8,P9,P10
# Out:
# (5537.3762510945362,
#  5634.913221601375,
#  5717.444504337931,
#  5829.9871626150525,
#  5931.2755550644624,
#  6017.5582597435896,
#  6088.8352766524331,
#  6205.1293568721258,
#  6261.4006860106865,
#  6317.6720151492473)

# %%
e1=5642.649902-P1
e2=5861.72998-P2
e3=5866.77002-P3
e4=6163.020021-P4
e5=6110.060059-P5
e6=6351.560059-P6
e7=6428.660156-P7
e8=6624-P8
e9=6786.439941-P9
e10=6912.359863-P10
e1,e2,e3,e4,e5,e6,e7,e8,e9,e10
# Out:
# (105.27365090546391,
#  226.8167583986251,
#  149.32551566206894,
#  333.03285838494776,
#  178.78450393553794,
#  334.00179925641078,
#  339.82487934756682,
#  418.87064312787425,
#  525.03925498931312,
#  594.68784785075241)
